# %% [markdown]
# ## Sploty w NumPy

# %%
import numpy as np
h = [2, 1, 0]
x = [3, 4, 5]

y = np.convolve(x, h)
y
# Out:
# array([ 6, 11, 14,  5,  0])

# %% [markdown]
# ## Sploty w Tensorflow

# %%
import tensorflow as tf

# %%
inp = tf.Variable(tf.random_normal([1, 10, 10, 1]))
filtr = tf.Variable(tf.random_normal([3, 3, 1, 1]))

op = tf.nn.conv2d(inp, filtr, strides=[1,1,1,1], padding='VALID')
op2 = tf.nn.conv2d(inp, filtr, strides=[1,1,1,1], padding='SAME')

# Inicjalizacja sesji

init = tf.global_variables_initializer()
with tf.Session() as session:
    session.run(init)
    
    print("Input \n")
    print('{0} \n'.format(inp.eval()))
    print("Filter/Kernel \n")
    print('{0} \n'.format(filtr.eval()))
    print("Result/Feature Map with valid positions \n")
    result = session.run(op)
    print(result)
    print('\n')
    print("Result/Feature Map with padding \n")
    result2 = session.run(op2)
    print(result2)
# Out:
# Input
#
# [[[[ 0.73363763]
#    [ 1.00486612]
#    [-0.6496309 ]
#    [ 1.2858001 ]
#    [ 0.6190353 ]
#    [-0.25182539]
#    [-0.66256237]
#    [-0.08490536]
#    [-0.50633067]
#    [ 0.81752539]]
#
#   [[-0.41495374]
#    [-3.06037903]
#    [ 0.74272317]
#    [-0.69136113]
#    [ 1.10192633]
#    [-0.42758965]
#    [-0.18295141]
#    [-0.6119802 ]
#    [-1.28792965]
#    [ 0.90560114]]
#
#   [[-0.11253554]
#    [ 0.58621228]
#    [ 1.48153841]
#    [-1.01883733]
#    [ 0.57826704]
#    [-1.74427366]
#    [-1.32016122]
#    [-0.97890097]
#    [-1.24893999]
#    [-0.57565033]]
#
#   [[-0.36534694]
#    [-0.75233889]
#    [-1.59125936]
#    [ 0.20979933]
#    [-0.49340793]
#    [ 0.78715086]
#    [-0.02707004]
#    [-0.20799768]
#    [ 0.3740893 ]
#    [ 0.14294961]]
#
#   [[-0.74139631]
#    [ 0.17877559]
#    [-0.98036647]
#    [-1.0475589 ]
#    [ 0.35173613]
#    [-1.33607972]
#    [ 2.26477194]
#    [ 0.27406308]
#    [-0.23794384]
#    [ 0.03050298]]
#
#   [[ 0.23866434]
# ...

# %% [markdown]
# ## Aplikowanie splotów do obrazów

# %%
# Pobranie obrazu
# !wget --quiet https://ibm.box.com/shared/static/cn7yt7z10j8rx6um1v9seagpgmzzxnlz.jpg --output-document bird.jpg

# %%
import numpy as np
from scipy import signal
from scipy import misc
import matplotlib.pyplot as plt
from PIL import Image

# %%
im = Image.open('bird.jpg')

# %%
# konwertowanie do skali szarości za pomocą transformacji
# ITU-R 601-2 Luma

im_gr = im.convert('L')

# %%
# Konwertowanie do arraya uint8
arr = np.asarray(im_gr)

# %%
# %matplotlib inline

# %%
# Rysowanie obrazu
imgplot  = plt.imshow(arr)
imgplot.set_cmap('gray')
plt.show(imgplot)

# %%
# Teraz, przykładowy splot 
kernel = np.array([
    [0, 1, 0],
    [1, -4, 1],
    [0, 1, 0]
])

# %%
grad =  signal.convolve2d(arr, kernel, mode='same', boundary='symm')

# %%
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(10, 10))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %%
type(grad)

grad_biases = np.absolute(grad) + 100

grad_biases[grad_biases > 255] = 255

# %%
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(10, 10))
aux.imshow(np.absolute(grad_biases), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map
