# %%
# %matplotlib inline
import numpy as np
np.random.seed(7)
import matplotlib.pyplot as plt

# %% [markdown]
# * [Wprowadzenie do szeregów czasowych i modelu
# ARIMA](http://www2.im.uj.edu.pl/katedry/seminaria/inda/wp-content/uploads/szeregi-wstep.pdf)
# * [Introduction to Time Series Analysis. Lecture 4.](https://www.stat.berkeley.edu/~bartlett/courses/153-fall2010/lectures/4.pdf)
# * [Modelowanie szeregów czasowych. Stacjonarność. Testy pierwiastka
# jednostkowego. Modele ARDL. Kointegracja](http://web.sgh.waw.pl/~jmuck/Ekonometria/EkonometriaPrezentacja2017L_5.pdf)
# * [Lesson 5: The Autocovariance Function of a
# stochastic process](http://www.phdeconomics.sssup.it/documents/Lesson5.pdf)

# %%
# Biały szum 
white_noise_tm = np.random.rand(300)
plt.figure(figsize=(15,5))
plt.plot(white_noise_tm)

# %%
am_noise_based = np.array([white_noise_tm[i-2]+.9*white_noise_tm[i-1]+white_noise_tm[i] for i in range(2, len(white_noise_tm))])

# %%
plt.figure(figsize=(15,5))
plt.plot(am_noise_based)

# %% [markdown]
# * średnia
# * autokowariancja
# * autokorelacja
# * kowariancja dwóch szeregów
# * korelacja dwóch szeregów

# %% [markdown]
# # Autokowariancja

# %% [markdown]
# $\gamma(s,t) = E[(x_s-\mu_s)(x_t - \mu_t)]$
